# %%
import tweepy
import pandas as pd

# %%
# Variables that contain the user credentials to access Twitter API
API_KEY = 'E1q0U2IlTlrbfw2D8dR6t66w1'
API_KEY_SECRET = '0aJ1Ni1bTllJZG18nQgpEkEcc9SR0cM9Vwu9N6ifLi2Yf8PjDn'
ACCESS_TOKEN = '321798811-Czv7S4z5zW0LiukCjOlBnpr4nltfEE5EbtyuDaqC'
ACCESS_TOKEN_SECRET = 'ybydHVavn4528ivocX5BqPT99LHrHSU5J76oFPXrfobYA'

# %%
auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
text_query = 'wildfire -filter:retweets'
count = 100
lang = 'en'
#until = '2020-8-19'
try:
 # Creation of query method using parameters
 tweets = tweepy.Cursor(api.search,q=text_query,lang = lang).items(count)
 
 # Pulling information from tweets iterable object
 tweets_list = [[tweet.created_at, tweet.id, tweet.text] for tweet in tweets]
 
 # Creation of dataframe from tweets list
 # Add or remove columns as you remove tweet information
 tweets_df = pd.DataFrame(tweets_list)
 
except BaseException as e:
    print('failed on_status,',str(e))
    time.sleep(3)

# %%
tweets = tweets_df.rename(columns = {0:'CreatedOn',1:'ID',2:'Text'})

# %%
tweets.head(20)
# Out:
#              CreatedOn                   ID  \
# 0  2020-10-23 18:33:37  1319708572964433925
# 1  2020-10-23 18:33:08  1319708452894040066
# 2  2020-10-23 18:32:54  1319708393360269319
# 3  2020-10-23 18:31:50  1319708126010982400
# 4  2020-10-23 18:31:43  1319708093698220032
# 5  2020-10-23 18:30:12  1319707715262959625
# 6  2020-10-23 18:30:07  1319707693045764097
# 7  2020-10-23 18:30:01  1319707668446171137
# 8  2020-10-23 18:29:07  1319707441899208709
# 9  2020-10-23 18:28:50  1319707370595979265
# 10 2020-10-23 18:28:06  1319707184255684608
# 11 2020-10-23 18:27:50  1319707118837039105
# 12 2020-10-23 18:27:49  1319707111794696192
# 13 2020-10-23 18:27:26  1319707016114376707
# 14 2020-10-23 18:27:00  1319706908501049344
# 15 2020-10-23 18:26:35  1319706803886821378
# 16 2020-10-23 18:26:24  1319706757275541505
# 17 2020-10-23 18:25:53  1319706626710962178
# 18 2020-10-23 18:25:23  1319706502161002497
# 19 2020-10-23 18:24:58  1319706394266865666
#
#                                                  Text
# 0   Rocky Mountain National Park is consuming my t...
# 1   how tf did yall say it was a man, spreading in...
# 2   Perfect outfit to go out isn't it? But the boo...
# 3   We must burn the West to save it https://t.co/...
# 4   @ethelred_horse Guess we'll just have to be fr...
# 5   "Anxiety spreads like wildfire in a home." Whe...
# 6   "Make sure you have a working carbon monoxide ...
# 7   WILDFIRE NAMES: Why name them? And how are the...
# 8   @SweetGoatato Yeah once they hand tame, it get...
# 9   @JohnCornyn @KimStrassel @WSJ 225,000 dead. In...
# 10                @Wildfire_draft Yes! It's so weird!
# 11  About to go out, to titillate all of the secre...
# 12  Firefighters..File a Claim Today! Click: https...
# 13  @hpjcjss1 @BaseballDo Was going to message you...
# 14  COLORADO: Updated Animal Assistance Info:\n#An...
# 15  @Zambiesaurusrex 30s? Little cold for Texas is...
# 16  Saw this dude doling out molly at WildFire a f...
# 17  @WajahatAli It's the truth!  New Delhi on a no...
# 18  @SCmimiga Weight? I have a lot actually. Like ...
# 19  @Venice_1987 I read an interesting article a f...

# %%
tweets.to_csv("recent_tweets.csv", index=False)

# %%
tweets = tweepy.Cursor(api.search, q=text_query).items(count)
# Pulling information from tweets iterable 
tweets_list = [[tweet.created_at, tweet.id, tweet.text, tweet.user, tweet.favorite_count] for tweet in tweets]
# Creation of dataframe from tweets list
tweets_df = pd.DataFrame(tweets_list)

# %%
tweets_df
# Out:
#                      0                    1  \
# 0  2020-10-13 21:23:33  1316127460937756673
# 1  2020-10-13 21:23:30  1316127446832279552
# 2  2020-10-13 21:23:26  1316127431833653250
# 3  2020-10-13 21:23:09  1316127358919868416
# 4  2020-10-13 21:22:52  1316127286131859460
# ..                 ...                  ...
# 95 2020-10-13 20:57:49  1316120985704202243
# 96 2020-10-13 20:57:44  1316120960995454976
# 97 2020-10-13 20:57:30  1316120904175411202
# 98 2020-10-13 20:57:21  1316120864665088011
# 99 2020-10-13 20:57:09  1316120816761876481
#
#                                                     2  \
# 0   RT @Goose: ($100.00) AWP | Wildfire - Giveaway...
# 1   One case of @BaerlicBrewing Keep Oregon Green ...
# 2   UPDATE on the enhanced wildfire/grass fire thr...
# 3   RT @Goose: ($100.00) AWP | Wildfire - Giveaway...
# 4   RT @Goose: ($100.00) AWP | Wildfire - Giveaway...
# ..                                                ...
# 95  RT @Goose: ($100.00) AWP | Wildfire - Giveaway...
# 96  RT @Epsilohcroc: For Halloween why not dress u...
# 97  RT @chiwilderness: Don't miss this! #ChicagoWi...
# 98  RT @altNOAA: Covid is surging in the Bible Bel...
# 99  RT @jilevin: Triple-digit temperatures, strong...
#
#                                                     3  4
# 0   User(_api=<tweepy.api.API object at 0x000001B4...  0
# 1   User(_api=<tweepy.api.API object at 0x000001B4...  0
# 2   User(_api=<tweepy.api.API object at 0x000001B4...  0
# 3   User(_api=<tweepy.api.API object at 0x000001B4...  0
# 4   User(_api=<tweepy.api.API object at 0x000001B4...  0
# ..                                                ... ..
# 95  User(_api=<tweepy.api.API object at 0x000001B4...  0
# 96  User(_api=<tweepy.api.API object at 0x000001B4...  0
# 97  User(_api=<tweepy.api.API object at 0x000001B4...  0
# 98  User(_api=<tweepy.api.API object at 0x000001B4...  0
# 99  User(_api=<tweepy.api.API object at 0x000001B4...  0
#
# [100 rows x 5 columns]
